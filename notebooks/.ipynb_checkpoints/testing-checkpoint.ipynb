# %%
import pandas as pd
import os
from sqlalchemy import create_engine, text

# %%
DB_HOST = os.getenv("DB_HOST", "db")
DB_PORT = os.getenv("DB_PORT", "5432")
DB_NAME = os.getenv("DB_NAME", "weather_db")
DB_USER = os.getenv("DB_USER", "postgres")
DB_PASSWORD = os.getenv("DB_PASSWORD", "postgres")

DATABASE_URL = (
    f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}"
    f"@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

# %%
DATABASE_URL
# Out:
# 'postgresql+psycopg2://postgres:postgres@db:5432/weather_db'

# %%
engine = create_engine(DATABASE_URL)

# %%
with engine.connect() as conn:
    loc_df = pd.read_sql("select * from location", conn)
    weather_df = pd.read_sql("select * from weather_observation", conn)

# %%
loc_df
# Out:
#                                      id      city state country  latitude  \
# 0  4065e54d-9f8f-47dc-9005-bbbd07c0c37d   Seattle    WA     USA   47.6062
# 1  be4123ad-30ea-4a1a-b68f-fb86e60048cd   Bothell    WA     USA   47.7623
# 2  f8ae1291-77d2-4b91-b6bf-1f3797951f8c  Portland    OR     USA   45.5152
#
#    longitude                       created_at
# 0  -122.3321 2026-05-15 04:13:02.485694+00:00
# 1  -122.2054 2026-05-15 04:13:02.485694+00:00
# 2  -122.6784 2026-05-15 04:13:02.485694+00:00

# %%
weather_df.head()
# Out:
#                                      id                           location_id  \
# 0  aaef5404-d311-456c-ab6d-d78b8f664929  be4123ad-30ea-4a1a-b68f-fb86e60048cd
# 1  2f12e9b3-2ee1-4aaa-a547-fa9dd5201805  be4123ad-30ea-4a1a-b68f-fb86e60048cd
# 2  c8e45e38-7860-434c-ab05-2df70ededafc  be4123ad-30ea-4a1a-b68f-fb86e60048cd
# 3  49742a1b-2e70-4292-868e-53cfdc84e510  be4123ad-30ea-4a1a-b68f-fb86e60048cd
# 4  e5ae6504-f14c-4304-a6c3-1b41e6be347c  be4123ad-30ea-4a1a-b68f-fb86e60048cd
#
#                 observed_at  temperature  feels_like  humidity pressure  \
# 0 2026-05-06 00:00:00+00:00         18.0        18.2      71.0     None
# 1 2026-05-06 01:00:00+00:00         18.1        18.2      70.0     None
# 2 2026-05-06 02:00:00+00:00         18.1        18.0      68.0     None
# 3 2026-05-06 03:00:00+00:00         17.3        17.1      68.0     None
# 4 2026-05-06 04:00:00+00:00         15.6        15.0      76.0     None
#
#    wind_speed weather_description  weather_code raw_json  \
# 0         3.9                None             1     None
# 1         5.1                None             1     None
# 2         4.8                None             0     None
# 3         4.0                None             0     None
# 4         7.1                None             0     None
#
#                         created_at
# 0 2026-05-15 04:13:03.858606+00:00
# 1 2026-05-15 04:13:03.858606+00:00
# 2 2026-05-15 04:13:03.858606+00:00
# 3 2026-05-15 04:13:03.858606+00:00
# 4 2026-05-15 04:13:03.858606+00:00

# %%
weather_df.dtypes
# Out:
# id                                  object
# location_id                         object
# observed_at            datetime64[us, UTC]
# temperature                        float64
# feels_like                         float64
# humidity                           float64
# pressure                            object
# wind_speed                         float64
# weather_description                 object
# weather_code                         int64
# raw_json                            object
# created_at             datetime64[us, UTC]
# dtype: object

# %%
combined = loc_df.merge(weather_df, left_on='id', right_on='location_id', suffixes=['_loc', '_wea'])

# %%
combined.head()
# Out:
#                                  id_loc     city state country  latitude  \
# 0  4065e54d-9f8f-47dc-9005-bbbd07c0c37d  Seattle    WA     USA   47.6062
# 1  4065e54d-9f8f-47dc-9005-bbbd07c0c37d  Seattle    WA     USA   47.6062
# 2  4065e54d-9f8f-47dc-9005-bbbd07c0c37d  Seattle    WA     USA   47.6062
# 3  4065e54d-9f8f-47dc-9005-bbbd07c0c37d  Seattle    WA     USA   47.6062
# 4  4065e54d-9f8f-47dc-9005-bbbd07c0c37d  Seattle    WA     USA   47.6062
#
#    longitude                   created_at_loc  \
# 0  -122.3321 2026-05-15 04:13:02.485694+00:00
# 1  -122.3321 2026-05-15 04:13:02.485694+00:00
# 2  -122.3321 2026-05-15 04:13:02.485694+00:00
# 3  -122.3321 2026-05-15 04:13:02.485694+00:00
# 4  -122.3321 2026-05-15 04:13:02.485694+00:00
#
#                                  id_wea                           location_id  \
# 0  0f58ccad-899d-4d16-9e99-9d3d6cb166bf  4065e54d-9f8f-47dc-9005-bbbd07c0c37d
# 1  de19357f-387b-486a-9697-beefff7266f5  4065e54d-9f8f-47dc-9005-bbbd07c0c37d
# 2  ff6f3ef9-bbef-4172-8a04-410d7f0cac9b  4065e54d-9f8f-47dc-9005-bbbd07c0c37d
# 3  05c085d9-08eb-4071-8c9d-8a2119b0f50b  4065e54d-9f8f-47dc-9005-bbbd07c0c37d
# 4  ddd8817d-c0af-4f1a-a808-1fe6532254e5  4065e54d-9f8f-47dc-9005-bbbd07c0c37d
#
#                 observed_at  temperature  feels_like  humidity pressure  \
# 0 2026-05-06 00:00:00+00:00         17.7        17.3      70.0     None
# 1 2026-05-06 01:00:00+00:00         17.3        16.9      72.0     None
# 2 2026-05-06 02:00:00+00:00         17.9        17.4      67.0     None
# 3 2026-05-06 03:00:00+00:00         16.3        15.8      72.0     None
# 4 2026-05-06 04:00:00+00:00         15.0        14.3      77.0     None
#
#    wind_speed weather_description  weather_code raw_json  \
# 0         7.6                None             3     None
# 1         7.8                None             1     None
# 2         7.2                None             0     None
# 3         6.2                None             0     None
# 4         6.8                None             0     None
#
#                     created_at_wea
# 0 2026-05-15 04:13:03.203481+00:00
# 1 2026-05-15 04:13:03.203481+00:00
# 2 2026-05-15 04:13:03.203481+00:00
# 3 2026-05-15 04:13:03.203481+00:00
# 4 2026-05-15 04:13:03.203481+00:00

# %%
combined.groupby('city')['temperature'].mean()
# Out:
# city
# Bothell     13.735833
# Portland    15.210833
# Seattle     13.050833
# Name: temperature, dtype: float64

# %%
combined.groupby('city')['feels_like'].mean()
# Out:
# city
# Bothell     12.984167
# Portland    14.781667
# Seattle     11.976667
# Name: feels_like, dtype: float64
